# %%
import pandas as pd
import numpy as np
from pandas_datareader import DataReader as pdr
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %% [markdown]
# ## Data

# %% [markdown]
# #### Returns from second_backtest

# %%
rets = pd.read_csv("files/rets_another_backtest.csv", parse_dates=["date"], index_col="date")
rets.index = rets.index.to_period("M")

# %% [markdown]
# #### Fama-French factors

# %%
ff = pdr("F-F_Research_Data_5_Factors_2x3", "famafrench", start=2005)[0]/100

# %% [markdown]
# #### Market and 130/30 returns

# %%
rets["mkt"] = ff["Mkt-RF"] + ff["RF"]
rets["ls"] = 1.3*rets["best"] - 0.3*rets["worst"]
rets["rf"] = ff["RF"]

# %% [markdown]
# ## Raw Returns

# %% [markdown]
# #### Accumulations

# %%
(1+rets[["best", "worst", "mkt", "ls"]]).cumprod().plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %% [markdown]
# #### Means and risks

# %%
print(12*rets[["best", "worst", "mkt", "ls"]].mean())
print(np.sqrt(12)*rets[["best", "worst", "mkt", "ls"]].std())
# Out:
# best     0.116603
# worst    0.063585
# mkt      0.109803
# ls       0.132509
# dtype: float64
# best     0.169795
# worst    0.353870
# mkt      0.150797
# ls       0.171079
# dtype: float64

# %% [markdown]
# #### Excess returns and Sharpe ratios

# %%
xrets = rets[["best", "worst", "mkt", "ls"]].subtract(rets.rf, axis=0)
sharpes = np.sqrt(12)*xrets.mean()/xrets.std()
sharpes
# Out:
# best     0.618020
# worst    0.147445
# mkt      0.651299
# ls       0.706983
# dtype: float64

# %% [markdown]
# #### 130/30 drawdowns

# %%
ls = (1+rets.ls).cumprod()
lsmax = ls.expanding().max()
drawdown = ls/lsmax - 1

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax2.set_yscale("log")
ax2.plot(rets.index.to_timestamp(), ls, 'b-')
ax1.plot(rets.index.to_timestamp(), drawdown, 'r-')

ax1.set_xlabel('Date')
ax2.set_ylabel('Accumulation (log scale)', color='b')
ax1.set_ylabel(' % Drawdown', color='r')
# Out:
# Text(0, 0.5, ' % Drawdown')

# %% [markdown]
# ## Market benchmark

# %% [markdown]
# #### Regressions on excess market return

# %%
tables = []
coefs = []
actives = []

for string in ["best~mkt", "worst~mkt", "ls~mkt"]:
    result = smf.ols(string, data=xrets).fit()
    tables.append(result.summary().tables[1])
    coefs.append(result.params)
    actives.append(result.params["Intercept"] + result.resid)

# %% [markdown]
# #### Regression tables

# %%
for table in tables:
    print(table)
# Out:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0014      0.002      0.671      0.503      -0.003       0.006
# mkt            0.8964      0.048     18.804      0.000       0.802       0.990
# ==============================================================================
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0097      0.005     -1.962      0.051      -0.019    4.75e-05
# mkt            1.7140      0.112     15.345      0.000       1.494       1.934
# ==============================================================================
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0048      0.003      1.656      0.099      -0.001       0.010
# mkt            0.6511      0.065     10.045      0.000       0.523       0.779
# ==============================================================================

# %% [markdown]
# #### Active returns and risks

# %%
actives = [pd.Series(x, index=xrets.index) for x in actives]
actives = pd.concat(actives, axis=1)
actives.columns = ["best", "worst", "ls"]
np.sqrt(12) * actives.std()
# Out:
# best     0.103205
# worst    0.241843
# ls       0.140333
# dtype: float64

# %% [markdown]
# #### Information ratios

# %%
info_ratios = np.sqrt(12)*actives.mean()/actives.std()
info_ratios
# Out:
# best     0.164798
# worst   -0.481885
# ls       0.406694
# dtype: float64

# %% [markdown]
# #### 130/30 breakdown into market and active returns

# %%
logy = True

beta = coefs[-1]["mkt"]

(1+rets.ls).cumprod().plot(label="long-short", logy=logy)
(1+ rets.rf + beta*xrets.mkt).cumprod().plot(label="market", logy=logy)
(1+actives.ls).cumprod().plot(label="active", logy=logy)
plt.legend()

# %% [markdown]
# ## Fama-French Benchmark

# %% [markdown]
# #### Fama-French factors

# %%
xrets[["smb", "hml", "rmw", "cma"]] = ff[["SMB", "HML", "RMW", "CMA"]]

# %% [markdown]
# #### Fama-French regressions

# %%
tables = []
coefs = []
actives = []

strings = [x+"~mkt+smb+hml+rmw+cma" for x in ["best", "worst", "ls"]]
for string in strings:
    result = smf.ols(string, data=xrets).fit()
    tables.append(result.summary().tables[1])
    coefs.append(result.params)
    actives.append(result.params["Intercept"] + result.resid)

# %% [markdown]
# #### Regression tables

# %%
for table in tables:
    print(table)
# Out:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0035      0.001      2.533      0.012       0.001       0.006
# mkt            0.6715      0.034     19.868      0.000       0.605       0.738
# smb            0.6102      0.060     10.125      0.000       0.491       0.729
# hml            0.5819      0.054     10.818      0.000       0.476       0.688
# rmw            0.1370      0.079      1.729      0.085      -0.019       0.293
# cma           -0.2598      0.096     -2.697      0.008      -0.450      -0.070
# ==============================================================================
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0050      0.004     -1.200      0.231      -0.013       0.003
# mkt            1.3733      0.104     13.191      0.000       1.168       1.579
# smb            1.3071      0.186      7.041      0.000       0.941       1.673
# hml           -0.1327      0.166     -0.801      0.424      -0.459       0.194
# rmw           -0.9610      0.244     -3.937      0.000      -1.442      -0.480
# cma            0.7079      0.297      2.386      0.018       0.123       1.293
# ==============================================================================
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0060      0.002      2.538      0.012       0.001       0.011
# mkt            0.4609      0.059      7.865      0.000       0.345       0.577
# smb            0.4011      0.105      3.838      0.000       0.195       0.607
# hml            0.7962      0.093      8.536      0.000       0.612       0.980
# rmw            0.4664      0.137      3.394      0.001       0.195       0.737
# cma           -0.5501      0.167     -3.293      0.001      -0.879      -0.221
# ==============================================================================

# %% [markdown]
# #### Active returns and risks

# %%
actives = [pd.Series(x, index=xrets.index) for x in actives]
actives = pd.concat(actives, axis=1)
actives.columns = ["best", "worst", "ls"]
np.sqrt(12) * actives.std()
# Out:
# best     0.063839
# worst    0.196657
# ls       0.110711
# dtype: float64

# %% [markdown]
# #### Information ratios

# %%
info_ratios = np.sqrt(12)*actives.mean()/actives.std()
info_ratios
# Out:
# best     0.649938
# worst   -0.308052
# ls       0.651365
# dtype: float64

# %% [markdown]
# #### 130/30 attribution analysis

# %%
logy = True

betas = coefs[-1]

(1+rets.ls).cumprod().plot(label="long-short", logy=logy)
(1 + rets.rf + betas["mkt"]*xrets.mkt).cumprod().plot(label="market", logy=logy)
(1 + betas["smb"]*xrets.smb).cumprod().plot(label="smb", logy=logy)
(1 + betas["hml"]*xrets.hml).cumprod().plot(label="hml", logy=logy)
(1 + betas["rmw"]*xrets.rmw).cumprod().plot(label="rmw", logy=logy)
(1 + betas["cma"]*xrets.cma).cumprod().plot(label="cma", logy=logy)
(1+actives.ls).cumprod().plot(label="active", logy=logy)
plt.legend()

# %% [markdown]
# ## Investing in SPY

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (0.2.4)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: html5lib>=1.1 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from yfinance) (1.24.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from yfinance) (39.0.0)
# Requirement already satisfied: requests>=2.26 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from yfinance) (2.28.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: soupsieve>1.2 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from requests>=2.26->yfinance) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: pycparser in c:\users\keb7\repos\mgmt767-binder\venv\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf

spy = yf.download('spy', start='2004-01-01', progress=False)['Adj Close']
spy = spy.resample('M').last()
spy = spy.pct_change().dropna()
spy.index = spy.index.to_period('M')
# Out:
# C:\Users\keb7\AppData\Local\Temp\ipykernel_49428\3975516332.py:6: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   spy.index = spy.index.to_period('M')

# %%
rets["spy"] = spy
rets["ls_spy"] = rets.spy + 0.3*rets.best - 0.3*rets.worst
